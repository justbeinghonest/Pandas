# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv(r'annual-enterprise-survey-2021-financial-year-provisional-csv.csv')
df1 = df.pivot_table('Total',index='Finance',aggfunc=np.count_nonzero,columns=['Dollars (millions)']).plot()

plt.show()
