# %%
import pandas as pd 
import matplotlib.pyplot as plt
df = pd.read_csv(r'India_GDP_1960-2022.csv')

fig,ax = plt.subplots(2,2)

ax[0,0].bar(df['Year'],df['Growth %'],color='red')
ax[0,1].bar(df['Year'],df['GDP in (Billion) $'],color='blue')
ax[1,0].plot(df['Year'],df['Per Capita in rupees'],color='green')
ax[1,1].barh(df['Year'],df['Per Capita in rupees'],color='green')
plt.show()

print(df.head())
# Out:
#    Year  GDP in (Billion) $  Per Capita in rupees  Growth %
# 0  2021             3173.40                182160      8.95
# 1  2020             2667.69                154640     -6.60
# 2  2019             2831.55                165760      3.74
# 3  2018             2702.93                159840      6.45
# 4  2017             2651.47                158480      6.80
